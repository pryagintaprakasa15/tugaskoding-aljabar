# %%
import numpy as np

# %%
# buat matrix X berukuran 2x3 menggunakan numpy
x = np.array([[25, 1, 5], [61, 0, 93],])
x
# Out:
# array([[25,  1,  5],
#        [61,  0, 93]])

# %%
# tampilkan ukuran dari matrix x
x.shape
# Out:
# (2, 3)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x[0:,]
# Out:
# array([[25,  1,  5],
#        [61,  0, 93]])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x[:,1]
# Out:
# array([1, 0])

# %%
import torch

# %%
# buat matrix X berukuran 2x3 menggunakan pytorch
x_pt = torch.tensor([[25, 15, 6], [1, 0, 93],])
x_pt
# Out:
# tensor([[25, 15,  6],
#         [ 1,  0, 93]])

# %%
# tampilkan ukuran dari matrix x
x_pt.shape
# Out:
# torch.Size([2, 3])

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x_pt[0,:]
# Out:
# tensor([25, 15,  6])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X

x_pt[:,1]
# Out:
# tensor([15,  0])

# %%
import tensorflow as tf

# %%
# buat matrix X berukuran 2x3 menggunakan tensorflow
x_tf = tf.Variable([[25, 15, 66], [1, 0, 93],])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[25, 15, 66],
#        [ 1,  0, 93]], dtype=int32)>

# %%
# tampilkan ukuran dari matrix x
tf.shape(x_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2, 3], dtype=int32)>

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x_tf[0,:]
# Out:
# <tf.Tensor: shape=(3,), dtype=int32, numpy=array([25, 15, 66], dtype=int32)>

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x_tf[:,1]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([15,  0], dtype=int32)>
