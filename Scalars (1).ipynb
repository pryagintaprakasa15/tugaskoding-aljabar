# %% [markdown]
# **Scalars**

# %%
x = 2515
x
# Out:
# 2515

# %%
y = 1093
y
# Out:
# 1093

# %%
py_sum = x + y
py_sum
# Out:
# 3608

# %%
type(py_sum)
# Out:
# int

# %%
x_float = 93.01
float_sum = x_float + y
float_sum
# Out:
# 1186.01

# %%
type(float_sum)
# Out:
# float

# %% [markdown]
# **Scalars in TensorFlow**

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(93)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=93>

# %% [markdown]
# **Scalars in PyTorch**

# %%
import torch

# %%
x_pt = torch.tensor(93)
x_pt
# Out:
# tensor(93)
