# %%
x = 2515
x
# Out:
# 2515

# %%
y = 1093
y
# Out:
# 1093

# %%
py_sum = x + y
py_sum
# Out:
# 3608

# %%
type(py_sum)
# Out:
# int

# %%
x_float = 93.01
float_sum = x_float + y
float_sum
# Out:
# 1186.01

# %%
type(float_sum)
# Out:
# float
